# %%
# Case Study1 on Class Marks By using with CS-3 and CS-4 codes
# K.madhukar Reddy
# 2211cs010290
# CSE Group-4

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("class_marks.csv")
df["percent"]=((df["Total"]/120)*10).round()
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6  percent
# 0     4.0    6.0      3.0
# 1     NaN    NaN      3.0
# ...

# %% [markdown]
# TOTAL values are sorted in ascending order above.

# %%
df = df.fillna(0).astype(int)

# %%
DF=df.sort_values("Total",ascending=True)
DF
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 69      3      1      0      1      0      0      0      1      0      0
# 11      8      2      2      0      3      1      0      0      0      0
# 23      9      4      3      0      0      0      0      0      0      0
# 22     14      4      4      5      2      0      0      0      0      0
# 57     17      3      0      0      4      0      0      3      7      0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73     40      4      6      0      0      5      5      3      0     10
# 53     40      4      6      6      4      5      5      0      0     10
# 51     40      0      0      6      4      0      0      3      7     10
# 33     40      0      0      6      4      5      5      3      7      0
# 65     40      4      6      6      4      5      5      0      0     10
#
#     Q6aM4  Q6bM6  percent
# 69      0      0        0
# 11      0      0        1
# ...

# %%
df.head()
# Out:
#    Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0     37      4      5      6      4      2      1      0      5      8
# 1     32      4      3      4      3      0      0      3      6      9
# 2     33      4      5      5      1      5      5      0      0      8
# 3     24      4      6      6      3      2      2      0      0      0
# 4     36      3      6      4      4      5      4      0      0     10
#
#    Q6aM4  Q6bM6  percent
# 0      4      6        3
# 1      0      0        3
# 2      0      0        3
# 3      2      0        2
# 4      0      0        3

# %%
df.loc[(df.Total<=26)].Total.count()
# Out:
# 28

# %%
df.loc[(df.Total<=20)].Total.count()
# Out:
# 12

# %%
df.tail()
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6  percent
# 81      4      6        3
# 82      3      5        2
# 83      4      6        3
# 84      0      0        2
# 85      1      4        2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Total    86 non-null     int32
#  1   Q1aM4    86 non-null     int32
#  2   Q1bM6    86 non-null     int32
#  3   Q2aM6    86 non-null     int32
#  4   Q2bM4    86 non-null     int32
#  5   Q3aM5    86 non-null     int32
#  6   Q3bM5    86 non-null     int32
#  7   Q4aM3    86 non-null     int32
#  8   Q4bM7    86 non-null     int32
#  9   Q5M10    86 non-null     int32
#  10  Q6aM4    86 non-null     int32
#  11  Q6bM6    86 non-null     int32
#  12  percent  86 non-null     int32
# dtypes: int32(13)
# memory usage: 4.5 KB

# %%
DF['Q1']=DF["Q1aM4"]+DF["Q1bM6"]
DF['Q2']=DF['Q2aM6']+DF['Q2bM4']
DF['Q3']=DF['Q3aM5']+DF['Q3bM5']
DF['Q4']=DF['Q4aM3']+DF['Q4bM7']
DF['Q6']=DF['Q6aM4']+DF['Q6bM6']
DF.fillna(0)
DF
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 69      3      1      0      1      0      0      0      1      0      0
# 11      8      2      2      0      3      1      0      0      0      0
# 23      9      4      3      0      0      0      0      0      0      0
# 22     14      4      4      5      2      0      0      0      0      0
# 57     17      3      0      0      4      0      0      3      7      0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73     40      4      6      0      0      5      5      3      0     10
# 53     40      4      6      6      4      5      5      0      0     10
# 51     40      0      0      6      4      0      0      3      7     10
# 33     40      0      0      6      4      5      5      3      7      0
# 65     40      4      6      6      4      5      5      0      0     10
#
#     Q6aM4  Q6bM6  percent  Q1  Q2  Q3  Q4  Q6
# ...

# %%
df.loc[(df["Total"]>20) & (df["Total"]<=30),["Grade"]]="Third"
df.loc[(df["Total"]>=16) & (df["Total"]<=20),["Grade"]]="Pass"
df.loc[(df["Total"]<16)& (df["Total"]>=0),["Grade"]]="Fail"
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37      4      5      6      4      2      1      0      5      8
# 1      32      4      3      4      3      0      0      3      6      9
# 2      33      4      5      5      1      5      5      0      0      8
# 3      24      4      6      6      3      2      2      0      0      0
# 4      36      3      6      4      4      5      4      0      0     10
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6  percent  Grade
# 0       4      6        3    NaN
# ...

# %% [markdown]
# New Columns Q1,Q2,Q3,Q4,Q6 are created above to do
# analysis.

# %%
a=DF.loc[(DF['Total'] >= 14) & (DF['Total'] <= 19)]
a=a.reset_index()
a.fillna(0)
# Out:
#    index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0     22     14      4      4      5      2      0      0      0      0
# 1     57     17      3      0      0      4      0      0      3      7
# 2     76     17      2      3      4      2      4      2      0      0
# 3     63     18      4      0      4      2      0      0      0      0
# 4     34     19      2      3      3      1      2      3      0      0
#
#    Q5M10  Q6aM4  Q6bM6  percent  Q1  Q2  Q3  Q4  Q6
# 0      0      0      0        1   8   7   0   0   0
# 1      0      4      0        1   3   4   0  10   4
# 2      0      0      0        1   5   6   6   0   0
# 3      8      0      0        2   4   6   0   0   0
# 4      5      0      0        2   5   4   5   0   0

# %% [markdown]
# Total marks 14-19 is filtered above

# %%
a1=a.groupby('Q1')['Total']
a1.hist(color = 'gray',figsize=[8,8],grid=False,bins=1)
plt.title("Histogram of students who scored 14-19 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q1")
plt.show()

# %% [markdown]
# Most of the students scored 2 mark,implying that all the students in this range secured
# very less marks in Q1

# %%
a2=a.groupby('Q2')['Total']
a2.hist(color='green',figsize=[8,8],grid=False,bins=1)
plt.title("Histogram of students who scored 14-19 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q2")
plt.show()

# %% [markdown]
# Very few students got high marks in Q2 overall performance in Q2 is not upto the
# mark but some students got 2 marks

# %%
a3=a.groupby('Q3')['Total']
a3.hist(color='blue',figsize=[8,8],grid=False,bins=2)
plt.title("Histogram of students who scored 14-19 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q3")
plt.show()

# %% [markdown]
# only two students got 2 marks implying very less marks are secured in
# Q3 overall

# %%
a4=a.groupby('Q4')['Total']
a2.hist(color='green',figsize=[8,8],grid=False,bins=1)
plt.title("Histogram of students who scored 14-19 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q4")
plt.show()

# %% [markdown]
# Only one student got 2 marks attempted Q4 got less
# marks

# %%
a5=a.groupby('Q5M10')['Total']
a5.hist(color='orange',figsize=[8,8],grid=False,bins=3)
plt.title("Histogram of students who scored 14-19 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q5")
plt.show()

# %% [markdown]
# the students who attempted Q5 got less
# marks and maximum mark is also just one only

# %%
a6=a.groupby('Q6')['Total']
a6.hist(color='purple',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 14-19 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q6")
plt.show()

# %% [markdown]
#  few students are attempted Q6 but one student scored 2 marks

# %%
b=DF.loc[(DF['Total'] >= 15) & (DF['Total'] <= 25)]
b=b.reset_index()
b.fillna(0)
b
# Out:
#     index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0      57     17      3      0      0      4      0      0      3      7
# 1      76     17      2      3      4      2      4      2      0      0
# 2      63     18      4      0      4      2      0      0      0      0
# 3      34     19      2      3      3      1      2      3      0      0
# 4      68     20      4      6      6      4      0      0      0      0
# 5       5     20      4      6      6      4      0      0      0      0
# 6      60     20      2      5      3      2      0      0      0      0
# 7      30     20      4      4      4      4      5      0      0      0
# 8      54     21      2      6      0      0      5      5      3      0
# 9      75     21      4      0      6      1      1      1      0      0
# 10     77     22      4      5      0      0      3      2      2      0
# 11     39     22      3      2      0      1      3      3      0      0
# ...

# %%
DF.fillna(0)
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 69      3      1      0      1      0      0      0      1      0      0
# 11      8      2      2      0      3      1      0      0      0      0
# 23      9      4      3      0      0      0      0      0      0      0
# 22     14      4      4      5      2      0      0      0      0      0
# 57     17      3      0      0      4      0      0      3      7      0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73     40      4      6      0      0      5      5      3      0     10
# 53     40      4      6      6      4      5      5      0      0     10
# 51     40      0      0      6      4      0      0      3      7     10
# 33     40      0      0      6      4      5      5      3      7      0
# 65     40      4      6      6      4      5      5      0      0     10
#
#     Q6aM4  Q6bM6  percent  Q1  Q2  Q3  Q4  Q6
# ...

# %% [markdown]
# Total marks 15-25 is filtered from the data set

# %%
b.plot.scatter(x='Q1',y='Total',color='gray',s=50)
plt.title("15-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# Majority of the students in this range scored marks
# between 6-10 in Q1 and very few, just 3 students scored
# below 5 marks, maximum mark scored is 10 by two
# students.

# %%
b.plot.scatter(x='Q2',y='Total',color='red',s=40)
plt.title("15-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# one student got lessthan 5 marks,those who have attempted scored marks between 7 and 10 overall. Maximum mark is 10 scored
# by three students.

# %%
b.plot.scatter(x='Q3',y='Total',color='black',s=40)
plt.title("15-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# Two students have attempted but they got lessthan 5marks the question and
# most of them who attempted scored 5-7 marks and
# maximum mark is 10 scored by three students.

# %%
b.plot.scatter(x='Q4',y='Total',color='blue',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# very few student are  attempted but students is scored very less marks ,maximum mark
# is 10 by two student.

# %%
b.plot.scatter(x='Q5M10',y='Total',color='purple',s=40)
plt.title("15-25 Marks ANALYSIS")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Majority of the students who attempted scored marks
# between 5 and 8, but one student got 9 marks

# %%
b.plot.scatter(x='Q6',y='Total',color='purple',s=40)
plt.title("15-25 Marks ANALYSIS")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# very few students are attempted,but two students are scored 10 marks

# %%
c=DF.loc[(DF['Total'] >= 20) & (DF['Total'] <= 30)]
c=c.reset_index()
c
# Out:
#     index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0      68     20      4      6      6      4      0      0      0      0
# 1       5     20      4      6      6      4      0      0      0      0
# 2      60     20      2      5      3      2      0      0      0      0
# 3      30     20      4      4      4      4      5      0      0      0
# 4      54     21      2      6      0      0      5      5      3      0
# 5      75     21      4      0      6      1      1      1      0      0
# 6      77     22      4      5      0      0      3      2      2      0
# 7      39     22      3      2      0      1      3      3      0      0
# 8      25     22      4      2      5      2      4      3      2      0
# 9      61     24      4      5      6      4      0      5      0      0
# 10     18     24      3      3      5      3      0      0      2      1
# 11     50     24      4      5      0      0      5      5      0      0
# ...

# %%
c.fillna(0)
# Out:
#     index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0      68     20      4      6      6      4      0      0      0      0
# 1       5     20      4      6      6      4      0      0      0      0
# 2      60     20      2      5      3      2      0      0      0      0
# 3      30     20      4      4      4      4      5      0      0      0
# 4      54     21      2      6      0      0      5      5      3      0
# 5      75     21      4      0      6      1      1      1      0      0
# 6      77     22      4      5      0      0      3      2      2      0
# 7      39     22      3      2      0      1      3      3      0      0
# 8      25     22      4      2      5      2      4      3      2      0
# 9      61     24      4      5      6      4      0      5      0      0
# 10     18     24      3      3      5      3      0      0      2      1
# 11     50     24      4      5      0      0      5      5      0      0
# ...

# %% [markdown]
# Total marks 25-30 is filtered from the data set

# %%
c.boxplot(by='Q1', column =['Total'], grid = False,color='Green',figsize=[6,6])
plt.title("20-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many of the students in this range got marks between 5
# and 10, the maximum mark is 10 and minimum mark is
# 0.

# %%
c.boxplot(by='Q2', column =['Total'], grid = False,color='red',figsize=[6,6])
plt.title("20-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Majority of the students who attempted the question in
# this range scored marks between 7 and 10
# The maximum mark is 10 whereas minimum mark is
# 0.

# %%
c.boxplot(by='Q3', column =['Total'], grid = False,color='blue',figsize=[5,6])
plt.title("20-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Majority of the students who attempted the question in
# this range scored marks between 7 and 10
# The maximum mark is 10 whereas minimum mark is
# 0.

# %%
c.boxplot(by='Q4', column =['Total'], grid = False,color='red',figsize=[5,6])
plt.title("20-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# No student in this range secured full mark for this
# question
# Minimum mark is 0 and the ones who attempted
# secured low marks.

# %%
c.boxplot(by='Q5M10', column =['Total'], grid = False,color='purple',figsize=[5,6])
plt.title("20-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# It can be observed that many students scored marks
# between 4 and 9, the minimum mark remains 0 and
# none of the students scored full marks in this
# question.

# %%
c.boxplot(by='Q6', column =['Total'], grid = False,color='maroon',figsize=[5,6])
plt.title("20-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many of them didn't attempt this question so minimum
# mark remains 0, but one student is scored full mark

# %%
d=DF.loc[(DF['Total']>=30) & (DF['Total']<=40)]
d=d.reset_index()
d
# Out:
#     index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0      35     30      4      6      6      4      0      1      0      0
# 1      14     30      4      6      6      2      4      5      3      0
# 2      16     30      4      0      6      4      5      2      0      0
# 3      80     31      4      6      6      2      2      5      0      0
# 4      66     31      4      5      5      2      5      3      1      5
# 5      37     31      4      4      6      4      0      0      0      0
# 6       1     32      4      3      4      3      0      0      3      6
# 7      15     32      3      0      2      1      5      5      3      7
# 8      27     32      2      6      6      1      5      5      3      3
# 9      13     32      3      3      6      4      3      5      0      0
# 10     32     32      4      6      6      4      2      0      0      0
# 11     81     32      3      6      3      4      5      3      0      0
# ...

# %%
d.fillna(0)
# Out:
#     index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0      35     30      4      6      6      4      0      1      0      0
# 1      14     30      4      6      6      2      4      5      3      0
# 2      16     30      4      0      6      4      5      2      0      0
# 3      80     31      4      6      6      2      2      5      0      0
# 4      66     31      4      5      5      2      5      3      1      5
# 5      37     31      4      4      6      4      0      0      0      0
# 6       1     32      4      3      4      3      0      0      3      6
# 7      15     32      3      0      2      1      5      5      3      7
# 8      27     32      2      6      6      1      5      5      3      3
# 9      13     32      3      3      6      4      3      5      0      0
# 10     32     32      4      6      6      4      2      0      0      0
# 11     81     32      3      6      3      4      5      3      0      0
# ...

# %%
d.plot.line(x='Q1',y='Total',color='red')
plt.title("Line Graph of Q1")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# It can be deduced from the above line graph that
# majority of the students in this range scored marks
# between 8 and 10.
#
# The maximum mark is 10 and minimum mark is 5
# meaning none of the students left the question
# unattempted.

# %%
d.plot.line(x='Q2',y='Total',color='green')
plt.title("Line Graph of Q2")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# The students who attempted this question scored
# marks between 8 and 10 overall, also the minimum
# mark is zero whereas the maximum mark is 10.

# %%
d.plot.line(x='Q3',y='Total',color='blue')
plt.title("Line Graph of Q3")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# The students in this range scored 7-10 marks on an
# average
#
# The maximum mark is 10 whereas minimum mark is 0,
# meaning some students did not attempt this
# question.

# %%
d.plot.line(x='Q4',y='Total',color='purple')
plt.title("Line Graph of Q4")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# no one  attempted the question

# %%
d.plot.line(x='Q5M10',y='Total',color='black')
plt.title("Line Graph of Q5")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Majority of the students who attempted this question
# scored marks between 7 and 10 overall.
#
# The maximum mark is 10 whereas minimum mark is 0,
# meaning some students left the question
# unattempted.

# %%
a['Q1'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of Q1")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Q1')

# %% [markdown]
# From the above pie chart we can deduce that most of
# the students who attempted the question scored marks
#  4 , the minimum mark is 0

# %%
a['Q2'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of Q2")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Q2')

# %% [markdown]
# Majority of the students who attempted the question
# scored better marks and very few scored 0

# %%
df.plot()
plt.show()

# %%
df['Q1']=df['Q1aM4']+df["Q1bM6"]
plt.hist(df['Q1'],color='red',edgecolor='black',bins=4)
plt.xlabel("Marks scored in Q1")
plt.ylabel("No.of students")
plt.title("Histogram of Q1")
# Out:
# Text(0.5, 1.0, 'Histogram of Q1')

# %% [markdown]
#  Majority of the students are attempted, but some students got lessthan 8 marks in Q1 and 50 students are scored 10 marks

# %%
df['Q2']=df['Q2aM6']+df["Q2bM4"]
plt.hist(df["Q2"],color='yellow',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q2")
plt.ylabel("No.of students")
plt.title("Histogram of Q2")
# Out:
# Text(0.5, 1.0, 'Histogram of Q2')

# %% [markdown]
# Majority of the students are attempted, but some students got less marks in Q2 and 40 students are scored 10 marks
# some students are scored between 7 to 9 marks

# %%
df['Q3']=df['Q3aM5']+df["Q3bM5"]
plt.hist(df["Q3"],color='orange',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q3")
plt.ylabel("No.of students")
plt.title("Histogram of Q3")
# Out:
# Text(0.5, 1.0, 'Histogram of Q3')

# %% [markdown]
# Majority of the students are attempted, but some students got less marks in Q3 and 30 students are scored 10 marks some students are scored between 7 to 9 marks

# %%
df['Q4']=df['Q4aM3']+df["Q4bM7"]
plt.hist(df["Q4"],color='green',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q4")
plt.ylabel("No.of students")
plt.title("Histogram of Q4")
# Out:
# Text(0.5, 1.0, 'Histogram of Q4')

# %% [markdown]
# very few students are attempted but some students scored between 6 to 9 marks and 10 students are scored 10 marks

# %%
plt.hist(df["Q5M10"],color='purple',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q5")
plt.ylabel("No.of students")
plt.title("Histogram of Q5")
# Out:
# Text(0.5, 1.0, 'Histogram of Q5')

# %% [markdown]
# Majority of the students are attempted, but some students got lessthan 6 marks in Q5 and 14 students are scored 10 marks some students are scored between 7 to 9 marks

# %%
df.plot.scatter(x = 'Q1', y = 'Total',color='blue',edgecolors='black',s=30)
plt.title("Scatter Plot for Q1")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q1')

# %%
df.plot.scatter(x = 'Q2', y = 'Total',color='blue',edgecolors='red',s=30)
plt.title("Scatter Plot for Q2")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q2')

# %%
df.plot.scatter(x = 'Q3', y = 'Total',color='red',edgecolors='blue',s=30)
plt.title("Scatter Plot for Q3")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q3')

# %%
df.plot.scatter(x = 'Q4', y = 'Total',color='gray',edgecolors='green',s=25)
plt.title("Scatter Plot for Q4")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q4')

# %%
df.plot.scatter(x = 'Q5M10', y = 'Total',color='black',edgecolors='red',s=25)
plt.title("Scatter Plot for Q5")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q5')

# %%
df.boxplot(by='Q1', column =['Total'], grid = False,color='Green')
plt.title("Boxplot of Q1")
plt.ylabel("Total")
plt.show()

# %%
df.boxplot(by='Q2', column =['Total'], grid = False,color='red')
plt.title("Boxplot of Q2")
plt.ylabel("Total")
plt.show()

# %%
df.boxplot(by='Q3', column =['Total'], grid = False,color='blue')
plt.title("Boxplot of Q3")
plt.ylabel("Total")
plt.show()

# %%
df.boxplot(by='Q4', column =['Total'], grid = False,color='Orange')
plt.title("Boxplot of Q4")
plt.ylabel("Total")
plt.show()

# %%
df.boxplot(by='Q5M10', column =['Total'], grid = False,color='purple')
plt.title("Boxplot of Q5")
plt.ylabel("Total")
plt.show()

# %%
df.plot.line(x='Q1',y='Total',color='red')
plt.title("Line Graph of Q1")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
df.plot.line(x='Q2',y='Total',color='green')
plt.title("Line Graph of Q2")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
df.plot.line(x='Q3',y='Total',color='blue')
plt.title("Line Graph of Q3")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
df.plot.line(x='Q4',y='Total',color='violet')
plt.title("Line Graph of Q4")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
df.plot.line(x='Q5M10',y='Total',color='purple')
plt.title("Line Graph of Q5")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
df["Q1"].plot(kind='pie',subplots=True,figsize=(9,14))
plt.title("Pie Chart of Q1")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Q1')

# %%
n=pd.read_csv("class_marks.csv",skiprows=50)
n
n['3'].plot(kind='pie',figsize=(8,10))
plt.title("Piechart of marks in Q2")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q2')

# %%
n=pd.read_csv("class_marks.csv",skiprows=60)
n
n['2'].plot(kind='pie',figsize=(8,10))
plt.title("Piechart of marks in Q3")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q3')

# %%
n=pd.read_csv("class_marks.csv",skiprows=60)
n
n['2'].plot(kind='pie',figsize=(8,10))
plt.title("Piechart of marks in Q4")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q4')

# %%
n=pd.read_csv("class_marks.csv",skiprows=70)
n
n['1.1'].plot(kind='pie',figsize=(8,10))
plt.title("Piechart of marks in Q5")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q5')

# %%
import seaborn as sns
sns.histplot(df)
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks")
plt.show()

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
sns.lineplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >
